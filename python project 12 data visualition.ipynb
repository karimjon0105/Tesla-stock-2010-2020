# %%
import matplotlib.pyplot as plt

#Tesla model S cars sold until now
labels = 2018,2019,2020,2021
sizes = [29950, 14425, 20301, 7857]
explode = (0.1, 0.1, 0.1, 0.1)        

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  


plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

years = [2015,2016,2017,2018,2019,2020,2021]

data = [97,2725,21600,27250,19600,26100,6306]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.6), startangle=0)

bbox_props = dict(boxstyle="square,pad=0.4", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0.3, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(years[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Tesla model X")

plt.show()

# %%
#Three lines to make our compiler able to draw:
import sys
import matplotlib


import numpy as np
import matplotlib.pyplot as plt

x = np.array([2017,2018,2019,2020,2021])
y = np.array([1667,140317,161100,206500,87911])

plt.plot(x, y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.ylabel("The number of cars", fontdict = font2)
plt.xlabel("Years", fontdict = font2)

plt.title("Tesla model 3", fontdict = font1)
#plt.plot(ypoints,xpoints, marker = 'o')
plt.grid(color = 'green', linestyle = '--', linewidth = 1)
plt.show()

# %%
import pandas as pd

mydataset = {
  'Model': ["MOdel S","Model S Plaid", "Model 3","Long Range AWD","Range and performance", "Model X","Model X plaid","Model Y performance","Model Y Long range AWD"],
  #power in horsepower
    'Peak Power': [670,1020,0,0,0,670,1020,0,0],
  #acceleration in second to 100km
    'Acceleration': [3.1,1.99,5.8,4.2,3.1,3.8,2.5,3.5,4.8],
   #price in dollars and potential savings
    'price': [88740,123740,38940,44940,52940,98940,113940,56940,51940],
   # weight in lbs
    'weight': [4561,4766,3582,4065,4065,5185,5390,4416,4416],
    'powertrain': ["Dual Motor","Tri motor","Rear-wheel Drive","Dual motor","Dual motor","Dual motor","Tri motor","Dual motor","Dual motor"],
    # in kW
    'supercharging': [250,250,170,250,250,250,250,"pay per use","pay per use"],
    #top speed in mph
    'top speed': [155,200,140,145,162,155,163,155,135],
    #range in miles
    'range': [405,396,272,358,315,348,333,303,330]
}
#myvar = pd.Series(mydataset)

#myvar = pd.DataFrame(mydataset)
df = pd.DataFrame(mydataset)


print(df)
# Out:
#                     Model  Peak Power  Acceleration   price  weight  \
# 0                 MOdel S         670          3.10   88740    4561
# 1           Model S Plaid        1020          1.99  123740    4766
# 2                 Model 3           0          5.80   38940    3582
# 3          Long Range AWD           0          4.20   44940    4065
# 4   Range and performance           0          3.10   52940    4065
# 5                 Model X         670          3.80   98940    5185
# 6           Model X plaid        1020          2.50  113940    5390
# 7     Model Y performance           0          3.50   56940    4416
# 8  Model Y Long range AWD           0          4.80   51940    4416
#
#          powertrain supercharging  top speed  range
# 0        Dual Motor           250        155    405
# 1         Tri motor           250        200    396
# 2  Rear-wheel Drive           170        140    272
# 3        Dual motor           250        145    358
# ...

# %%
import sys
import matplotlib


import matplotlib.pyplot as plt
import numpy as np

plt.rcdefaults()
fig, ax = plt.subplots()

x = np.array([2014, 2015, 2016, 2017,2018,2019,2020])
y = np.array([-294, -889, -675, -1962, -976,-862, 721])



plt.bar(x, y, width = 0.3)
ax.set_xlabel('cost in million US. dollars')
ax.set_title("Tesla's net income/loss from FY 2014 to FY 2020")
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
import sys
import matplotlib


import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([2014,2015,2016,2017,2018,2019,2020])
y = np.array([16669,25416,47644,50145,191627,192250,235000])

plt.subplot(1, 2, 1)
plt.plot(x,y)

plt.title("Annual Vehicle Sales Chart", loc= 'right')
plt.xlabel("Sales Unit")


#plot 2:
x = np.array([2014,2015,2016,2017,2018,2019,2020])
y = np.array([0,52.29, 87.46, 5.25, 282.15, 0.33, 222.00])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.xlabel("  Growth")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# data from United Nations World Population Prospects (Revision 2019)
# https://population.un.org/wpp/, license: CC BY 3.0 IGO
year = [2015,2016,2017,2018,2019,2020,2021]
population_by_continent = {
    'Tesla S': [0,0,0,29950, 14425, 20301, 7857],
    'Tesla 3': [0,0,1667,140317,161100,206500,87911],
    'Tesla x': [97,2725,21600,27250,19600,26100,6306],
    'Tesla y': [0,0,0,0,0,25000,121229]
   
}

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys())
ax.legend(loc='upper left')
ax.set_title('How many Tesla model cars have been sold from 2015 to 2021', fontdict = font1)
ax.set_xlabel('Years', fontdict = font2)
ax.set_ylabel('Number of cars ', fontdict = font2)
# Out:
# Text(0, 0.5, 'Number of cars ')
